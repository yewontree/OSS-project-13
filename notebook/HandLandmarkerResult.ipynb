# %%
import sys
sys.path.insert(0, '..') # 상위 폴더를 python import path에 추가

# %%
import inspect
from typing import TypeVar


# https://stackoverflow.com/questions/13520421/recursive-dotdict
class attrdict(dict):
    """
    a dictionary that supports dot operation
    as well as dictionary access operation
    usage: d = attrdict() or d = attrdict({'val1':'first'})
    set attributes: d.val2 = 'second' or d['val2'] = 'second'
    get attributes: d.val2 or d['val2']
    """

    __getattr__ = dict.__getitem__
    __setattr__ = dict.__setitem__
    __delattr__ = dict.__delitem__


def attr(obj) -> tuple[attrdict, attrdict, attrdict, attrdict]:
    """Tool for python object inspection. Python object has its namespace and attribute.
    Python's built-in function 'dir' is useful, but inconvenient for object namespace analysis.
    So, this function renovates python's built-in functions like dir, var, ...

    Returns:
        tuple: (obj's state_types, obj's callable_signatures, state_values, and bounded callables)
    """
    all_attr = {}
    for attribute in dir(obj):
        if not attribute.startswith("_"):
            try:
                all_attr[attribute] = getattr(obj, attribute)
            except AttributeError:
                continue

    methods = dict([(k, v) for k, v in all_attr.items() if callable(v)])

    signatures = {}
    for k, v in all_attr.items():
        if callable(v):
            try:
                signatures[k] = inspect.signature(v)  # may occur ValueError
            except ValueError:
                signatures[k] = "No signature available for built-in method"

    state_keys = sorted(list(set(all_attr.keys()) - set(methods.keys())))
    state_types = dict([(k, type(getattr(obj, k))) for k in state_keys])
    state_values = dict([(k, getattr(obj, k)) for k in state_keys])

    return attrdict(state_types), attrdict(signatures), attrdict(state_values), attrdict(methods)

# %% [markdown]
# # Models
# https://developers.google.com/mediapipe/solutions/vision/hand_landmarker#models
#
# #####  HandLandmarker
# ![HandLandmarker](https://developers.google.com/static/mediapipe/images/solutions/hand-landmarks.png)
#
# ##### 활용 사례
# https://github.com/GasbaouiMohammedAlAmin/Finger-Counter-using-Hand-Tracking-And-Open-cv/blob/main/README.md
#
# ![Screenshop](https://github.com/GasbaouiMohammedAlAmin/Finger-Counter-using-Hand-Tracking-And-Open-cv/raw/main/fingerCounting.png)

# %% [markdown]
# ### [HandLandmarkerResult 분석](https://developers.google.com/mediapipe/solutions/vision/hand_landmarker/python#handle_and_display_results)
#  - mediapipe.tasks.python.vision.hand_landmarker.HandLandmarkerResult
#  - public abstract class HandLandmarkerResult
#  - Represents the hand landmarks deection results generated by HandLandmarker.

# %% [markdown]
# ##### main.py

# %%
import cv2
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
from mediapipe.tasks.python.vision.hand_landmarker import HandLandmarkerResult, HandLandmarker
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import numpy as np
import logging, coloredlogs

from settings import *  # loading settings.py data to current 'main' namespace
# Out:
# 2023-11-30 04:13:13 AERO15 settings[31488] INFO importing settings.py
# 2023-11-30 04:13:13 AERO15 settings[31488] INFO root 폴더: c:\Users\kclee\OneDrive\Develope\2023-2\OpenSW\OSS-project-13\notebook\..
# 2023-11-30 04:13:13 AERO15 settings[31488] INFO finger_tips index: [4, 8, 12, 16, 20]

# %%
logger = logging.getLogger(__name__)
coloredlogs.install(level="DEBUG", logger=logger)  # logger 설정, logger.debug() 함수로 로그메시지 표시


# https://github.com/googlesamples/mediapipe/blob/main/examples/hand_landmarker/python/hand_landmarker.ipynb
def draw_fingercount_on_image(rgb_image, detection_result):
    hand_landmarks_list = detection_result.hand_landmarks
    handedness_list = detection_result.handedness
    annotated_image = np.copy(rgb_image)

    # Loop through the detected hands to visualize.
    for idx in range(len(hand_landmarks_list)):
        hand_landmarks = hand_landmarks_list[idx]
        handedness = handedness_list[idx]

        # Draw the hand landmarks.
        hand_landmarks_proto = landmark_pb2.NormalizedLandmarkList()
        hand_landmarks_proto.landmark.extend(
            [landmark_pb2.NormalizedLandmark(x=landmark.x, y=landmark.y, z=landmark.z) for landmark in hand_landmarks]
        )
        solutions.drawing_utils.draw_landmarks(
            annotated_image,
            hand_landmarks_proto,
            solutions.hands.HAND_CONNECTIONS,
            solutions.drawing_styles.get_default_hand_landmarks_style(),
            solutions.drawing_styles.get_default_hand_connections_style(),
        )

        # Get the top left corner of the detected hand's bounding box.
        height, width, _ = annotated_image.shape
        x_coordinates = [landmark.x for landmark in hand_landmarks]
        y_coordinates = [landmark.y for landmark in hand_landmarks]
        text_x = int(min(x_coordinates) * width)
        text_y = int(min(y_coordinates) * height) - MARGIN

        # Draw handedness (left or right hand) on the image.
        cv2.putText(
            annotated_image,
            text=f"{handedness[0].category_name}",
            org=(text_x, text_y),
            fontFace=cv2.FONT_HERSHEY_DUPLEX,
            fontScale=FONT_SIZE,
            color=HANDEDNESS_TEXT_COLOR,
            thickness=FONT_THICKNESS,
            lineType=cv2.LINE_AA,
        )

    return annotated_image



base_options = python.BaseOptions(model_asset_path=root / "models/hand_landmarker.task")
options = vision.HandLandmarkerOptions(base_options=base_options, num_hands=2)
detector: HandLandmarker = vision.HandLandmarker.create_from_options(options)  # hand detector 객체 생성

cap = cv2.VideoCapture(0)

while True:
    success, image_origin = cap.read()
    if success:
        image = cv2.cvtColor(image_origin, cv2.COLOR_BGR2RGB)
        rgb_frame = mp.Image(image_format=mp.ImageFormat.SRGB, data=image)
        detection_result: HandLandmarkerResult = detector.detect(rgb_frame)  # hand landmarker result (num_hands=2, 양손 가능)

        if detection_result:  # detection_result 로그데이터 생성
            logger.debug(f"detection_result:\n {detection_result}")

        annotated_image = draw_fingercount_on_image(  # 원본 카메라 영상에 detection 결과를 합성하는 듯~
            rgb_image=image_origin,
            detection_result=detection_result,
        )

        cv2.imshow(f"Finger Counter", annotated_image)  # 동영상 재생
        if cv2.waitKey(1) & 0xFF == ord("q"):
            break
    else:
        print(f"cap.read() error")
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 2023-11-30 04:13:17 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9562605619430542, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.5808755159378052, y=0.6289367079734802, z=-5.679526680069102e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5309454798698425, y=0.6397871971130371, z=0.017679041251540184, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5039349794387817, y=0.6143357753753662, z=0.025267453864216805, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.48012492060661316, y=0.600614070892334, z=0.025102363899350166, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4580135643482208, y=0.5952573418617249, z=0.023774253204464912, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5354567170143127, y=0.5147090554237366, z=0.04379214346408844, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5008310675621033, y=0.4935920536518097, z=0.045884616672992706, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47156062722206116, y=0.5015540719032288, z=0.04143551364541054, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4505994915962219, y=0.5205115675926208, z=0.038659561425447464, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5382270812988281, y=0.4965343475341797, z=0.030471932142972946, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4876914322376251, y=0.481850802898407, z=0.03738022223114967, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4556773900985718, y=0.49918827414512634, z=0.03237060084939003, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4347298741340637, y=0.5229323506355286, z=0.027275970205664635, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5369827747344971, y=0.4844682812690735, z=0.015430104918777943, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4778244197368622, y=0.47912541031837463, z=0.018413715064525604, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44538161158561707, y=0.5030466914176941, z=0.012379362247884274, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4253174364566803, y=0.5307795405387878, z=0.006854178849607706, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5264543294906616, y=0.4792464077472687, z=0.0010776584967970848, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.472914457321167, y=0.4850154221057892, z=0.004751467611640692, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44492587447166443, y=0.5060080885887146, z=0.005726233124732971, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.42488229274749756, y=0.532034158706665, z=0.00548681290820241, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.013911966234445572, y=0.06668571382761002, z=-0.04874981939792633, visibility=0.0, presence=0.0), Landmark(x=0.0047775693237781525, y=0.06647985428571701, z=-0.017698634415864944, visibility=0.0, presence=0.0), Landmark(x=-0.01027286984026432, y=0.05367632582783699, z=0.009900870732963085, visibility=0.0, presence=0.0), Landmark(x=-0.025289155542850494, y=0.04794156551361084, z=0.039029765874147415, visibility=0.0, presence=0.0), Landmark(x=-0.040217891335487366, y=0.04123595356941223, z=0.07509846985340118, visibility=0.0, presence=0.0), Landmark(x=0.0020238838624209166, y=0.010769459418952465, z=0.02421073243021965, visibility=0.0, presence=0.0), Landmark(x=-0.01575639843940735, y=0.0007516378536820412, z=0.031273312866687775, visibility=0.0, presence=0.0), Landmark(x=-0.03364456817507744, y=0.0005813343450427055, z=0.040338415652513504, visibility=0.0, presence=0.0), Landmark(x=-0.05020388215780258, y=0.01230922807008028, z=0.039171479642391205, visibility=0.0, presence=0.0), Landmark(x=0.0019939092453569174, y=-0.0011033902410417795, z=0.00831055361777544, visibility=0.0, presence=0.0), Landmark(x=-0.025720272213220596, y=-0.01503163855522871, z=0.015313293784856796, visibility=0.0, presence=0.0), Landmark(x=-0.04772137477993965, y=-0.0013056695461273193, z=0.020898813381791115, visibility=0.0, presence=0.0), Landma ...
# 2023-11-30 04:13:17 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:17 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9883179664611816, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6083387732505798, y=0.6209033727645874, z=-5.573701287175936e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5481443405151367, y=0.634080171585083, z=0.008924123831093311, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5075777173042297, y=0.6085047721862793, z=0.01051394920796156, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4706461429595947, y=0.5937634706497192, z=0.00571277504786849, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44267207384109497, y=0.5844789147377014, z=0.0003058214788325131, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5734833478927612, y=0.4577152132987976, z=0.033640868961811066, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.531286895275116, y=0.43372032046318054, z=0.03570295870304108, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5027869939804077, y=0.45157498121261597, z=0.03053784929215908, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.48672813177108765, y=0.47704318165779114, z=0.026613853871822357, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5694923400878906, y=0.4463355839252472, z=0.023833563551306725, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5061936974525452, y=0.4271371066570282, z=0.03000989370048046, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4718422293663025, y=0.45900681614875793, z=0.025621768087148666, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4571113884449005, y=0.49579182267189026, z=0.02065012790262699, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5588663816452026, y=0.4496951997280121, z=0.011891644448041916, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4909040629863739, y=0.4465152621269226, z=0.012758953496813774, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4555957317352295, y=0.48398417234420776, z=0.005585853010416031, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4397469460964203, y=0.5235632658004761, z=-0.0008041905821301043, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5382379293441772, y=0.4671076238155365, z=0.00025414928677491844, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.484863817691803, y=0.46583980321884155, z=0.0018455339595675468, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45620837807655334, y=0.49128788709640503, z=0.0024902524892240763, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4373723864555359, y=0.5221124887466431, z=0.0021098917350172997, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.008367550559341908, y=0.06623256206512451, z=-0.0453597716987133, visibility=0.0, presence=0.0), Landmark(x=0.003012392669916153, y=0.059449903666973114, z=-0.019919199869036674, visibility=0.0, presence=0.0), Landmark(x=-0.017206547781825066, y=0.05158103629946709, z=0.002745875855907798, visibility=0.0, presence=0.0), Landmark(x=-0.03537850081920624, y=0.04747465252876282, z=0.02539985254406929, visibility=0.0, presence=0.0), Landmark(x=-0.052242133766412735, y=0.03809257596731186, z=0.04489172622561455, visibility=0.0, presence=0.0), Landmark(x=0.0018940430600196123, y=0.003919757436960936, z=0.0180783960968256, visibility=0.0, presence=0.0), Landmark(x=-0.011133317835628986, y=-0.006125401705503464, z=0.02702580764889717, visibility=0.0, presence=0.0), Landmark(x=-0.022867782041430473, y=-0.005123743321746588, z=0.039846617728471756, visibility=0.0, presence=0.0), Landmark(x=-0.03568920120596886, y=0.008262399584054947, z=0.04240037128329277, visibility=0.0, presence=0.0), Landmark(x=0.001979487482458353, y=-0.0018466371111571789, z=0.007391616236418486, visibility=0.0, presence=0.0), Landmark(x=-0.02303425967693329, y=-0.01604107767343521, z=0.017303407192230225, visibility=0.0, presence=0.0), Landmark(x=-0.04153040796518326, y=-0.0030865296721458435, z=0.0240279920399189, visibility=0.0, presence=0.0),  ...
# 2023-11-30 04:13:17 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9804178476333618, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6047112345695496, y=0.6261876821517944, z=-5.312377879818087e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5365088582038879, y=0.6378498673439026, z=0.007243887521326542, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4969586730003357, y=0.6095352172851562, z=0.007787136826664209, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4614633023738861, y=0.5946912169456482, z=0.0022728745825588703, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.43405449390411377, y=0.5839627981185913, z=-0.003639509668573737, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5628597140312195, y=0.4596764147281647, z=0.029059268534183502, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5178534984588623, y=0.42353466153144836, z=0.028153298422694206, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4876522421836853, y=0.4398587644100189, z=0.022723985835909843, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4705858826637268, y=0.4650372862815857, z=0.019502753391861916, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5654590129852295, y=0.4493280351161957, z=0.019554924219846725, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.503329336643219, y=0.42122167348861694, z=0.02376379817724228, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4691586494445801, y=0.4482609033584595, z=0.019473906606435776, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4521522521972656, y=0.4804609715938568, z=0.014977982267737389, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5599367022514343, y=0.45268625020980835, z=0.00772811658680439, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4920518398284912, y=0.4427618980407715, z=0.005812959745526314, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45567038655281067, y=0.4755779802799225, z=-0.0018483042949810624, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4370450973510742, y=0.5124456286430359, z=-0.007799555081874132, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5429659485816956, y=0.4677615165710449, z=-0.0036387480795383453, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.48563918471336365, y=0.4663165211677551, z=-0.005745473317801952, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45565012097358704, y=0.49031415581703186, z=-0.006615931633859873, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.43473106622695923, y=0.5207359790802002, z=-0.007014227099716663, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.009187574498355389, y=0.0705249235033989, z=-0.030119087547063828, visibility=0.0, presence=0.0), Landmark(x=-0.0007818862795829773, y=0.06287465989589691, z=-0.005708274897187948, visibility=0.0, presence=0.0), Landmark(x=-0.018946204334497452, y=0.05252060666680336, z=0.011835643090307713, visibility=0.0, presence=0.0), Landmark(x=-0.03856177628040314, y=0.04518980532884598, z=0.031960081309080124, visibility=0.0, presence=0.0), Landmark(x=-0.05406467244029045, y=0.03609213978052139, z=0.05265428498387337, visibility=0.0, presence=0.0), Landmark(x=0.000334716634824872, y=0.0028788854833692312, z=0.020285002887248993, visibility=0.0, presence=0.0), Landmark(x=-0.014625300653278828, y=-0.009284645318984985, z=0.026815205812454224, visibility=0.0, presence=0.0), Landmark(x=-0.028307495638728142, y=-0.008859099820256233, z=0.03923506289720535, visibility=0.0, presence=0.0), Landmark(x=-0.0416918620467186, y=0.004014360718429089, z=0.044507790356874466, visibility=0.0, presence=0.0), Landmark(x=0.0023905234411358833, y=-0.0016801736783236265, z=0.007049113046377897, visibility=0.0, presence=0.0), Landmark(x=-0.022659439593553543, y=-0.01851712353527546, z=0.0137399323284626, visibility=0.0, presence=0.0), Landmark(x=-0.04031192511320114, y=-0.007859211415052414, z=0.025749927386641502, visibility=0.0, pres ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9882079362869263, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6243027448654175, y=0.6102378964424133, z=-6.489807446996565e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5811459422111511, y=0.6034615635871887, z=-0.005714967846870422, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.553046703338623, y=0.5741196274757385, z=-0.01622140221297741, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.519395649433136, y=0.5455061197280884, z=-0.030419066548347473, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49225351214408875, y=0.520189106464386, z=-0.045429885387420654, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.6049116253852844, y=0.41408687829971313, z=-0.007031146436929703, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.542583703994751, y=0.3820551931858063, z=-0.027509266510605812, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5103806257247925, y=0.41615918278694153, z=-0.044417351484298706, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49711260199546814, y=0.46225541830062866, z=-0.05288422480225563, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5937314033508301, y=0.41305017471313477, z=-0.012406555004417896, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49714040756225586, y=0.4140705466270447, z=-0.02915411815047264, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4642150402069092, y=0.46902626752853394, z=-0.04216615483164787, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45455533266067505, y=0.5219550728797913, z=-0.04990158602595329, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5739657878875732, y=0.43194064497947693, z=-0.019500182941555977, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4818413257598877, y=0.44721177220344543, z=-0.03875250369310379, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4513484835624695, y=0.5014568567276001, z=-0.048020314425230026, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44142216444015503, y=0.5512740612030029, z=-0.05134923383593559, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5477570295333862, y=0.4643143117427826, z=-0.026409728452563286, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4817267656326294, y=0.47173166275024414, z=-0.04044131562113762, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4526054859161377, y=0.4984266757965088, z=-0.04343324899673462, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.434744268655777, y=0.5269030332565308, z=-0.042173586785793304, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.012062345631420612, y=0.06121816113591194, z=-0.0015505035407841206, visibility=0.0, presence=0.0), Landmark(x=0.006535068154335022, y=0.04795059934258461, z=0.011790757067501545, visibility=0.0, presence=0.0), Landmark(x=-0.00823307316750288, y=0.04105767607688904, z=0.023902226239442825, visibility=0.0, presence=0.0), Landmark(x=-0.02457449398934841, y=0.03364593908190727, z=0.04659479856491089, visibility=0.0, presence=0.0), Landmark(x=-0.04210168495774269, y=0.02382693998515606, z=0.06575222313404083, visibility=0.0, presence=0.0), Landmark(x=0.0031367067713290453, y=-0.0014574178494513035, z=0.01437030453234911, visibility=0.0, presence=0.0), Landmark(x=-0.013472016900777817, y=-0.011388025246560574, z=0.017401816323399544, visibility=0.0, presence=0.0), Landmark(x=-0.024992818012833595, y=-0.00802789069712162, z=0.025485312566161156, visibility=0.0, presence=0.0), Landmark(x=-0.03562341257929802, y=0.012579461559653282, z=0.02471465989947319, visibility=0.0, presence=0.0), Landmark(x=0.0015213766600936651, y=-0.0022550097201019526, z=0.004118490498512983, visibility=0.0, presence=0.0), Landmark(x=-0.02859709970653057, y=-0.009504127316176891, z=0.008789099752902985, visibility=0.0, presence=0.0), Landmark(x=-0.04891733080148697, y=0.0060979705303907394, z=0.020967524498701096, visibility=0.0, p ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9882079362869263, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6243027448654175, y=0.6102378964424133, z=-6.489807446996565e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5811459422111511, y=0.6034615635871887, z=-0.005714967846870422, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.553046703338623, y=0.5741196274757385, z=-0.01622140221297741, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.519395649433136, y=0.5455061197280884, z=-0.030419066548347473, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49225351214408875, y=0.520189106464386, z=-0.045429885387420654, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.6049116253852844, y=0.41408687829971313, z=-0.007031146436929703, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.542583703994751, y=0.3820551931858063, z=-0.027509266510605812, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5103806257247925, y=0.41615918278694153, z=-0.044417351484298706, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49711260199546814, y=0.46225541830062866, z=-0.05288422480225563, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5937314033508301, y=0.41305017471313477, z=-0.012406555004417896, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49714040756225586, y=0.4140705466270447, z=-0.02915411815047264, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4642150402069092, y=0.46902626752853394, z=-0.04216615483164787, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45455533266067505, y=0.5219550728797913, z=-0.04990158602595329, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5739657878875732, y=0.43194064497947693, z=-0.019500182941555977, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4818413257598877, y=0.44721177220344543, z=-0.03875250369310379, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4513484835624695, y=0.5014568567276001, z=-0.048020314425230026, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44142216444015503, y=0.5512740612030029, z=-0.05134923383593559, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5477570295333862, y=0.4643143117427826, z=-0.026409728452563286, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4817267656326294, y=0.47173166275024414, z=-0.04044131562113762, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4526054859161377, y=0.4984266757965088, z=-0.04343324899673462, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.434744268655777, y=0.5269030332565308, z=-0.042173586785793304, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.012062345631420612, y=0.06121816113591194, z=-0.0015505035407841206, visibility=0.0, presence=0.0), Landmark(x=0.006535068154335022, y=0.04795059934258461, z=0.011790757067501545, visibility=0.0, presence=0.0), Landmark(x=-0.00823307316750288, y=0.04105767607688904, z=0.023902226239442825, visibility=0.0, presence=0.0), Landmark(x=-0.02457449398934841, y=0.03364593908190727, z=0.04659479856491089, visibility=0.0, presence=0.0), Landmark(x=-0.04210168495774269, y=0.02382693998515606, z=0.06575222313404083, visibility=0.0, presence=0.0), Landmark(x=0.0031367067713290453, y=-0.0014574178494513035, z=0.01437030453234911, visibility=0.0, presence=0.0), Landmark(x=-0.013472016900777817, y=-0.011388025246560574, z=0.017401816323399544, visibility=0.0, presence=0.0), Landmark(x=-0.024992818012833595, y=-0.00802789069712162, z=0.025485312566161156, visibility=0.0, presence=0.0), Landmark(x=-0.03562341257929802, y=0.012579461559653282, z=0.02471465989947319, visibility=0.0, presence=0.0), Landmark(x=0.0015213766600936651, y=-0.0022550097201019526, z=0.004118490498512983, visibility=0.0, presence=0.0), Landmark(x=-0.02859709970653057, y=-0.009504127316176891, z=0.008789099752902985, visibility=0.0, presence=0.0), Landmark(x=-0.04891733080148697, y=0.0060979705303907394, z=0.020967524498701096, visibility=0.0, p ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9947085976600647, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6161395907402039, y=0.6123448610305786, z=-6.200657480803784e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5507029294967651, y=0.6181219220161438, z=-0.003286836901679635, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.506755530834198, y=0.5958094596862793, z=-0.012175281532108784, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4670545756816864, y=0.5815118551254272, z=-0.025860078632831573, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4391501545906067, y=0.5637555122375488, z=-0.03961825743317604, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5766314268112183, y=0.4456530809402466, z=0.004610214848071337, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5224361419677734, y=0.41222336888313293, z=-0.012108477763831615, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.48906436562538147, y=0.4401463568210602, z=-0.026975851505994797, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47293543815612793, y=0.479288786649704, z=-0.03465549647808075, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5766153335571289, y=0.4383358061313629, z=-0.0024642508942633867, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49776744842529297, y=0.4275498390197754, z=-0.017138507217168808, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4630422294139862, y=0.4715587794780731, z=-0.03004058450460434, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4513604938983917, y=0.5176325440406799, z=-0.037094276398420334, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5686461925506592, y=0.44456908106803894, z=-0.011808558367192745, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4899303615093231, y=0.4482533633708954, z=-0.027944032102823257, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4551679491996765, y=0.49504271149635315, z=-0.03780142590403557, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4422379434108734, y=0.5399215221405029, z=-0.041433144360780716, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.551685094833374, y=0.4634692370891571, z=-0.02120383083820343, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4919610321521759, y=0.46365681290626526, z=-0.03159990906715393, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.46043676137924194, y=0.4890081286430359, z=-0.034033309668302536, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44067054986953735, y=0.5187000036239624, z=-0.03292305767536163, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.011168383993208408, y=0.06559771299362183, z=-0.012185796163976192, visibility=0.0, presence=0.0), Landmark(x=0.0002675047144293785, y=0.05573926493525505, z=0.004799229092895985, visibility=0.0, presence=0.0), Landmark(x=-0.020862668752670288, y=0.04630609601736069, z=0.022238703444600105, visibility=0.0, presence=0.0), Landmark(x=-0.04238622263073921, y=0.042732857167720795, z=0.044445425271987915, visibility=0.0, presence=0.0), Landmark(x=-0.059350188821554184, y=0.030911728739738464, z=0.0629376471042633, visibility=0.0, presence=0.0), Landmark(x=-0.0009669066057540476, y=0.0003716376959346235, z=0.019017722457647324, visibility=0.0, presence=0.0), Landmark(x=-0.01797432266175747, y=-0.009566626511514187, z=0.020381789654493332, visibility=0.0, presence=0.0), Landmark(x=-0.03128017857670784, y=-0.005885587073862553, z=0.028149040415883064, visibility=0.0, presence=0.0), Landmark(x=-0.043833065778017044, y=0.013516824692487717, z=0.024422552436590195, visibility=0.0, presence=0.0), Landmark(x=0.0009922198951244354, y=-0.0024861099664121866, z=0.0065946499817073345, visibility=0.0, presence=0.0), Landmark(x=-0.027728360146284103, y=-0.012126781046390533, z=0.009486677125096321, visibility=0.0, presence=0.0), Landmark(x=-0.04962916672229767, y=0.0032820384949445724, z=0.015579103492200375, visibilit ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9747315645217896, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6481879353523254, y=0.6009584665298462, z=-5.983870892123377e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5928426384925842, y=0.5966205596923828, z=-0.006586740724742413, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5511685609817505, y=0.5771998167037964, z=-0.021321024745702744, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5047425627708435, y=0.5605581998825073, z=-0.04024959355592728, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4743340313434601, y=0.5358315110206604, z=-0.061115995049476624, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.6261630654335022, y=0.4120926558971405, z=-0.010188613086938858, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5724071264266968, y=0.36869290471076965, z=-0.0302441343665123, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5381030440330505, y=0.40228480100631714, z=-0.048378366976976395, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5234025716781616, y=0.45157647132873535, z=-0.05795522406697273, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.6137658357620239, y=0.406148761510849, z=-0.015684081241488457, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5219297409057617, y=0.38812607526779175, z=-0.0281169805675745, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47912824153900146, y=0.44270217418670654, z=-0.04180514067411423, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4683074355125427, y=0.5014423727989197, z=-0.051218606531620026, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5925200581550598, y=0.4218306243419647, z=-0.022381838411092758, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49819138646125793, y=0.42346617579460144, z=-0.03413394093513489, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4602789878845215, y=0.4777469038963318, z=-0.04279077798128128, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45053377747535706, y=0.530791163444519, z=-0.048325274139642715, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5644950866699219, y=0.4531691074371338, z=-0.02948683686554432, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4936988651752472, y=0.46158406138420105, z=-0.037593353539705276, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.46300646662712097, y=0.48915591835975647, z=-0.03864311799407005, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4496747851371765, y=0.518408477306366, z=-0.03739210590720177, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.01049930602312088, y=0.05055733025074005, z=-0.020872458815574646, visibility=0.0, presence=0.0), Landmark(x=0.002768964972347021, y=0.04242510348558426, z=-0.0076629286631941795, visibility=0.0, presence=0.0), Landmark(x=-0.01653476059436798, y=0.039451729506254196, z=0.011597536504268646, visibility=0.0, presence=0.0), Landmark(x=-0.03584127873182297, y=0.03643295168876648, z=0.03842366486787796, visibility=0.0, presence=0.0), Landmark(x=-0.04855271801352501, y=0.024935660883784294, z=0.0635242834687233, visibility=0.0, presence=0.0), Landmark(x=-0.0023361206986010075, y=-0.001362873357720673, z=0.012772750109434128, visibility=0.0, presence=0.0), Landmark(x=-0.009761758148670197, y=-0.01464906893670559, z=0.018520919606089592, visibility=0.0, presence=0.0), Landmark(x=-0.020429588854312897, y=-0.013215193524956703, z=0.024697979912161827, visibility=0.0, presence=0.0), Landmark(x=-0.031145846471190453, y=0.007515955716371536, z=0.022022858262062073, visibility=0.0, presence=0.0), Landmark(x=-3.542449849192053e-05, y=-0.001632393104955554, z=0.005783178377896547, visibility=0.0, presence=0.0), Landmark(x=-0.02333972603082657, y=-0.01590028963983059, z=0.013402896001935005, visibility=0.0, presence=0.0), Landmark(x=-0.045131437480449677, y=-0.002853438491001725, z=0.019923238083720207, visibility=0.0, ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9862335920333862, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.615206778049469, y=0.6112084984779358, z=-5.04198283124424e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5598856210708618, y=0.6201094388961792, z=0.008480241522192955, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5256872177124023, y=0.595527172088623, z=0.010786281898617744, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4966208040714264, y=0.5789327025413513, z=0.006558673921972513, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4738125503063202, y=0.5621320605278015, z=0.0022072058636695147, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5725072622299194, y=0.4822361469268799, z=0.03165976330637932, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5282701253890991, y=0.4672854542732239, z=0.024190792813897133, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.49363774061203003, y=0.47782155871391296, z=0.012783201411366463, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.46993181109428406, y=0.4996129274368286, z=0.006052028853446245, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5755961537361145, y=0.46596822142601013, z=0.01980382576584816, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5172320604324341, y=0.44991469383239746, z=0.017153067514300346, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.48177576065063477, y=0.47009390592575073, z=0.009024060331285, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45996302366256714, y=0.499124139547348, z=0.0035512107424438, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5722827911376953, y=0.4593353271484375, z=0.005213387310504913, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5100222826004028, y=0.4478127956390381, z=-9.397313260706142e-05, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4739234745502472, y=0.46974676847457886, z=-0.00545107014477253, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4522634744644165, y=0.49777650833129883, z=-0.008303776383399963, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.560088038444519, y=0.46276727318763733, z=-0.009710296057164669, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5067211389541626, y=0.4571092128753662, z=-0.014082774519920349, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4758148491382599, y=0.4720150828361511, z=-0.014940568245947361, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45435455441474915, y=0.49311333894729614, z=-0.014243293553590775, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.01338883489370346, y=0.07327734678983688, z=-0.03712031617760658, visibility=0.0, presence=0.0), Landmark(x=-0.0010338909924030304, y=0.06753312796354294, z=-0.011333150789141655, visibility=0.0, presence=0.0), Landmark(x=-0.01852569729089737, y=0.056589990854263306, z=0.016113055869936943, visibility=0.0, presence=0.0), Landmark(x=-0.040813639760017395, y=0.05042383074760437, z=0.045834410935640335, visibility=0.0, presence=0.0), Landmark(x=-0.05286015197634697, y=0.03740326315164566, z=0.07632990926504135, visibility=0.0, presence=0.0), Landmark(x=-0.0008148732595145702, y=0.009377249516546726, z=0.02423693798482418, visibility=0.0, presence=0.0), Landmark(x=-0.021969549357891083, y=-0.000938373152166605, z=0.026376528665423393, visibility=0.0, presence=0.0), Landmark(x=-0.04248412325978279, y=0.0010673897340893745, z=0.03326921910047531, visibility=0.0, presence=0.0), Landmark(x=-0.062437791377305984, y=0.018964579328894615, z=0.022164933383464813, visibility=0.0, presence=0.0), Landmark(x=0.0011673418339341879, y=-0.0020562121644616127, z=0.008423998951911926, visibility=0.0, presence=0.0), Landmark(x=-0.02684207633137703, y=-0.013958252035081387, z=0.011897974647581577, visibility=0.0, presence=0.0), Landmark(x=-0.054087597876787186, y=-0.0016904082149267197, z=0.011084336787462234, visibility=0.0, presen ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9929192066192627, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6298785209655762, y=0.6106622219085693, z=-5.168622578821669e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5624749660491943, y=0.6205645203590393, z=0.004237358924001455, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.531816303730011, y=0.6005620956420898, z=0.0002806565025821328, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.504472017288208, y=0.5869611501693726, z=-0.00975643191486597, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.48332133889198303, y=0.5700806379318237, z=-0.021408051252365112, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5830175280570984, y=0.4482099711894989, z=0.020084872841835022, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5277512073516846, y=0.44542500376701355, z=0.012045342475175858, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4902738928794861, y=0.47025883197784424, z=-0.002113392809405923, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4650847315788269, y=0.49797895550727844, z=-0.01147371530532837, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5802366137504578, y=0.437613844871521, z=0.00881973933428526, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5144031047821045, y=0.4371953010559082, z=0.008325501345098019, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47669053077697754, y=0.4696895480155945, z=-0.0026265722699463367, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45499080419540405, y=0.49982619285583496, z=-0.012249642983078957, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5714800357818604, y=0.4414511024951935, z=-0.004123459570109844, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5072398781776428, y=0.439808189868927, z=-0.0063615175895392895, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4709625840187073, y=0.4682016670703888, z=-0.014673423022031784, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45031851530075073, y=0.49697577953338623, z=-0.02165106311440468, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5562300682067871, y=0.4570677876472473, z=-0.017765790224075317, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5061628222465515, y=0.4525481164455414, z=-0.01833382062613964, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4748317003250122, y=0.46826171875, z=-0.01811898499727249, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4533810615539551, y=0.4901777505874634, z=-0.01801445335149765, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.017112882807850838, y=0.07181798666715622, z=-0.033514153212308884, visibility=0.0, presence=0.0), Landmark(x=0.0018942155875265598, y=0.06752544641494751, z=-0.004749758634716272, visibility=0.0, presence=0.0), Landmark(x=-0.016410108655691147, y=0.060497500002384186, z=0.02632306143641472, visibility=0.0, presence=0.0), Landmark(x=-0.035537704825401306, y=0.05562719330191612, z=0.07362572848796844, visibility=0.0, presence=0.0), Landmark(x=-0.04820072278380394, y=0.04354627802968025, z=0.11594204604625702, visibility=0.0, presence=0.0), Landmark(x=-0.002304813824594021, y=0.0037351420614868402, z=0.025452902540564537, visibility=0.0, presence=0.0), Landmark(x=-0.022126728668808937, y=-0.0014640885638073087, z=0.027632877230644226, visibility=0.0, presence=0.0), Landmark(x=-0.04348817095160484, y=0.0010638602543622255, z=0.03058907762169838, visibility=0.0, presence=0.0), Landmark(x=-0.06297087669372559, y=0.02263876050710678, z=0.01773589476943016, visibility=0.0, presence=0.0), Landmark(x=0.0005729504628106952, y=-0.002975933253765106, z=0.008950624614953995, visibility=0.0, presence=0.0), Landmark(x=-0.02950034663081169, y=-0.012335959821939468, z=0.012168718501925468, visibility=0.0, presence=0.0), Landmark(x=-0.056066058576107025, y=0.0031338902190327644, z=0.014634269289672375, visibility=0.0, presence ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9945265650749207, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6446558833122253, y=0.6150040626525879, z=-5.65840196031786e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5733715295791626, y=0.6094930171966553, z=-0.005806140135973692, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5295860767364502, y=0.5888767242431641, z=-0.01716701127588749, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4883972108364105, y=0.5761821269989014, z=-0.03352316468954086, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4622938632965088, y=0.5580058693885803, z=-0.04987829551100731, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.6164222955703735, y=0.4269351065158844, z=0.005366263445466757, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5547015070915222, y=0.39762455224990845, z=-0.010369202122092247, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5170137286186218, y=0.42865249514579773, z=-0.0271622221916914, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4945402145385742, y=0.46484315395355225, z=-0.037082549184560776, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.6107131242752075, y=0.4188382923603058, z=-0.0007812265539541841, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.525236189365387, y=0.4046049416065216, z=-0.013864968903362751, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4862372577190399, y=0.44931477308273315, z=-0.027461815625429153, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47050175070762634, y=0.49312490224838257, z=-0.03569823503494263, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5952281951904297, y=0.42792758345603943, z=-0.009062073193490505, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5112634301185608, y=0.42903947830200195, z=-0.02258276753127575, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47437387704849243, y=0.473182737827301, z=-0.0316479429602623, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45801979303359985, y=0.5149258375167847, z=-0.035390205681324005, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5703677535057068, y=0.4504145085811615, z=-0.01809140481054783, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5103915929794312, y=0.4504566192626953, z=-0.024944715201854706, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4784562885761261, y=0.4720926284790039, z=-0.025753727182745934, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45771944522857666, y=0.4977101981639862, z=-0.023931147530674934, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.00985452439635992, y=0.06838422268629074, z=-0.01712183840572834, visibility=0.0, presence=0.0), Landmark(x=-0.0013568699359893799, y=0.059581466019153595, z=0.0038365530781447887, visibility=0.0, presence=0.0), Landmark(x=-0.022968381643295288, y=0.049508240073919296, z=0.024779988452792168, visibility=0.0, presence=0.0), Landmark(x=-0.04855665564537048, y=0.04799073562026024, z=0.05210014060139656, visibility=0.0, presence=0.0), Landmark(x=-0.06283409893512726, y=0.037827372550964355, z=0.07804429531097412, visibility=0.0, presence=0.0), Landmark(x=0.0010928919073194265, y=-0.0012856563553214073, z=0.018813855946063995, visibility=0.0, presence=0.0), Landmark(x=-0.017831627279520035, y=-0.010484487749636173, z=0.022285601124167442, visibility=0.0, presence=0.0), Landmark(x=-0.032883450388908386, y=-0.0068124462850391865, z=0.031091760843992233, visibility=0.0, presence=0.0), Landmark(x=-0.048827286809682846, y=0.012172437272965908, z=0.028236865997314453, visibility=0.0, presence=0.0), Landmark(x=0.0014835543697699904, y=-0.0037934300489723682, z=0.006002457346767187, visibility=0.0, presence=0.0), Landmark(x=-0.03051755577325821, y=-0.015192450024187565, z=0.010293781757354736, visibility=0.0, presence=0.0), Landmark(x=-0.05335662513971329, y=-0.0007124551921151578, z=0.018707165494561195, visibili ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[[Category(index=1, score=0.9827490448951721, display_name='Left', category_name='Left')]], hand_landmarks=[[NormalizedLandmark(x=0.6314939856529236, y=0.6191743016242981, z=-5.829266456203186e-07, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5563323497772217, y=0.6163204908370972, z=0.004472148139029741, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5152425765991211, y=0.5907829999923706, z=-0.00040594584424979985, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4766908884048462, y=0.5754469037055969, z=-0.01239595003426075, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.44924959540367126, y=0.5538138747215271, z=-0.025774406269192696, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5935015082359314, y=0.4376417398452759, z=0.022309474647045135, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5378555059432983, y=0.41569483280181885, z=0.013641021214425564, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5035934448242188, y=0.4460102319717407, z=0.0006718512740917504, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4822855293750763, y=0.4839089810848236, z=-0.006839290726929903, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5910865068435669, y=0.42672470211982727, z=0.012230515480041504, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.51493239402771, y=0.4087410867214203, z=0.008646607398986816, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.47794294357299805, y=0.45163801312446594, z=-0.0014514420181512833, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4634299874305725, y=0.4960066080093384, z=-0.008091464638710022, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5806374549865723, y=0.43114516139030457, z=0.0004405395593494177, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5051178336143494, y=0.423725426197052, z=-0.004344085697084665, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.46931546926498413, y=0.4647805988788605, z=-0.01160274725407362, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4534471035003662, y=0.5066646933555603, z=-0.015607898123562336, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5624691843986511, y=0.4500208795070648, z=-0.011818190105259418, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.5061216354370117, y=0.44867250323295593, z=-0.012394490651786327, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.4756495952606201, y=0.46961432695388794, z=-0.011019265279173851, visibility=0.0, presence=0.0), NormalizedLandmark(x=0.45477283000946045, y=0.4974882900714874, z=-0.008690022863447666, visibility=0.0, presence=0.0)]], hand_world_landmarks=[[Landmark(x=0.009340419434010983, y=0.06972512602806091, z=-0.025379687547683716, visibility=0.0, presence=0.0), Landmark(x=-0.0037295310758054256, y=0.062001608312129974, z=-0.0020152567885816097, visibility=0.0, presence=0.0), Landmark(x=-0.02472604624927044, y=0.05255129933357239, z=0.020444508641958237, visibility=0.0, presence=0.0), Landmark(x=-0.0487947091460228, y=0.04863440617918968, z=0.05628296360373497, visibility=0.0, presence=0.0), Landmark(x=-0.0638088807463646, y=0.03649446740746498, z=0.0882834792137146, visibility=0.0, presence=0.0), Landmark(x=-0.0022946614772081375, y=0.00218163407407701, z=0.01997850276529789, visibility=0.0, presence=0.0), Landmark(x=-0.018894830718636513, y=-0.007517384830862284, z=0.025415964424610138, visibility=0.0, presence=0.0), Landmark(x=-0.03398314490914345, y=-0.004963242448866367, z=0.02984611503779888, visibility=0.0, presence=0.0), Landmark(x=-0.049726225435733795, y=0.013678544200956821, z=0.022732334211468697, visibility=0.0, presence=0.0), Landmark(x=0.0007639555260539055, y=-0.0021131664980202913, z=0.007657208945602179, visibility=0.0, presence=0.0), Landmark(x=-0.027216756716370583, y=-0.01806727424263954, z=0.010828778147697449, visibility=0.0, presence=0.0), Landmark(x=-0.05009065940976143, y=-0.0019988995045423508, z=0.01666187308728695, visibility=0. ...
# 2023-11-30 04:13:18 AERO15 __main__[31488] DEBUG detection_result:
# ...
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:38 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:39 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:40 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:41 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])
# 2023-11-30 04:13:42 AERO15 __main__[31488] DEBUG detection_result:
#  HandLandmarkerResult(handedness=[], hand_landmarks=[], hand_world_landmarks=[])

# %%
type(detection_result)
# Out:
# mediapipe.tasks.python.vision.hand_landmarker.HandLandmarkerResult

# %% [markdown]
# 📌 HandLandmarkerResult는 mediapipe.tasks.python.vision.hand_landmarker.py 파일에서 데이터클래스로 정의됨

# %%
from mediapipe.tasks.python.vision.hand_landmarker import HandLandmarkerResult
from mediapipe.tasks.python.components.containers.category import Category
from mediapipe.tasks.python.components.containers.landmark import NormalizedLandmark, Landmark

# %% [markdown]
# #### 🚩 HandLandmarkerResult 클래스
# ```python
# @dataclasses.dataclass
# class HandLandmarkerResult:
#   """The hand landmarks result from HandLandmarker, where each vector element represents a single hand detected in the image.
#
#   Attributes:
#     handedness: Classification of handedness.
#     hand_landmarks: Detected hand landmarks in normalized image coordinates.
#     hand_world_landmarks: Detected hand landmarks in world coordinates.
#   """
#
#   handedness: List[List[category_module.Category]]
#   hand_landmarks: List[List[landmark_module.NormalizedLandmark]]
#   hand_world_landmarks: List[List[landmark_module.Landmark]]
# ```

# %%
try:
    detection_result = HandLandmarkerResult()
except TypeError as e:
    logger.warning(e)
# Out:
# 2023-11-30 04:13:43 AERO15 __main__[31488] WARNING HandLandmarkerResult.__init__() missing 3 required positional arguments: 'handedness', 'hand_landmarks', and 'hand_world_landmarks'

# %%
attr(Category)[0]
# Out:
# {'category_name': NoneType,
#  'display_name': NoneType,
#  'index': NoneType,
#  'score': NoneType}

# %%
attr(NormalizedLandmark)[0]
# Out:
# {'presence': NoneType,
#  'visibility': NoneType,
#  'x': NoneType,
#  'y': NoneType,
#  'z': NoneType}

# %%
attr(Landmark())[0]
# Out:
# {'presence': NoneType,
#  'visibility': NoneType,
#  'x': NoneType,
#  'y': NoneType,
#  'z': NoneType}

# %% [markdown]
# #### 🚩 HandLandmarkerResult Example

# %%
HandLandmarkerResult(
    handedness=[[Category(index=1, score=0.9865500926971436, display_name="Left", category_name="Left")]],
    hand_landmarks=[
        [
            NormalizedLandmark(x=0.7697514295578003, y=0.6468967795372009, z=2.972396373479569e-07, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.668741762638092, y=0.6643492579460144, z=-0.040008749812841415, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.5648773312568665, y=0.6172918677330017, z=-0.06133072078227997, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.4947565197944641, y=0.5577317476272583, z=-0.08032052218914032, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.4326040744781494, y=0.526371419429779, z=-0.0983131155371666, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.5639973878860474, y=0.42474114894866943, z=-0.027148446068167686, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.5079708099365234, y=0.32789477705955505, z=-0.05173785239458084, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.480471134185791, y=0.2685859501361847, z=-0.07474029809236526, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.4576159119606018, y=0.21509180963039398, z=-0.09316738694906235, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.6137695908546448, y=0.3705744445323944, z=-0.030617333948612213, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.5645943880081177, y=0.23626628518104553, z=-0.049807462841272354, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.5348491668701172, y=0.1555137187242508, z=-0.06909414380788803, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.5079306960105896, y=0.08884336054325104, z=-0.08486079424619675, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.6730667352676392, y=0.34885501861572266, z=-0.040538471192121506, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.6328999996185303, y=0.22224289178848267, z=-0.06340891867876053, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.6061319708824158, y=0.14483919739723206, z=-0.08335975557565689, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.5819135904312134, y=0.07867544889450073, z=-0.09826647490262985, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.741492509841919, y=0.349530965089798, z=-0.05467082932591438, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.7340850830078125, y=0.24912577867507935, z=-0.07368527352809906, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.7289763689041138, y=0.18323004245758057, z=-0.08507121354341507, visibility=0.0, presence=0.0),
            NormalizedLandmark(x=0.7216171026229858, y=0.12328104674816132, z=-0.09445909410715103, visibility=0.0, presence=0.0),
        ]
    ],
    hand_world_landmarks=[
        [
            Landmark(x=0.046565815806388855, y=0.07342524081468582, z=0.006881324574351311, visibility=0.0, presence=0.0),
            Landmark(x=0.010594870895147324, y=0.07021936029195786, z=-0.007981224916875362, visibility=0.0, presence=0.0),
            Landmark(x=-0.014852593652904034, y=0.06191084906458855, z=-0.0166409183293581, visibility=0.0, presence=0.0),
            Landmark(x=-0.045510780066251755, y=0.04683224856853485, z=-0.025354573503136635, visibility=0.0, presence=0.0),
            Landmark(x=-0.06854020804166794, y=0.03167642652988434, z=-0.0283240657299757, visibility=0.0, presence=0.0),
            Landmark(x=-0.028759997338056564, y=0.014417590573430061, z=0.0012775243958458304, visibility=0.0, presence=0.0),
            Landmark(x=-0.04029626026749611, y=-0.010929192416369915, z=-0.008486682549118996, visibility=0.0, presence=0.0),
            Landmark(x=-0.050002872943878174, y=-0.025899965316057205, z=-0.02284790761768818, visibility=0.0, presence=0.0),
            Landmark(x=-0.059284575283527374, y=-0.0319778136909008, z=-0.05590397119522095, visibility=0.0, presence=0.0),
            Landmark(x=-0.007565224077552557, y=-0.0017618824495002627, z=0.008078535087406635, visibility=0.0, presence=0.0),
            Landmark(x=-0.021680276840925217, y=-0.038745105266571045, z=-0.006962615065276623, visibility=0.0, presence=0.0),
            Landmark(x=-0.03542018681764603, y=-0.056135863065719604, z=-0.02756108157336712, visibility=0.0, presence=0.0),
            Landmark(x=-0.047300662845373154, y=-0.06984193623065948, z=-0.05037245526909828, visibility=0.0, presence=0.0),
            Landmark(x=0.01660585217177868, y=-0.0115079116076231, z=-0.0009205307578667998, visibility=0.0, presence=0.0),
            Landmark(x=0.003100059926509857, y=-0.03883817046880722, z=-0.014047347940504551, visibility=0.0, presence=0.0),
            Landmark(x=-0.008930228650569916, y=-0.05718749761581421, z=-0.033243678510189056, visibility=0.0, presence=0.0),
            Landmark(x=-0.0204799622297287, y=-0.06876767426729202, z=-0.05420058220624924, visibility=0.0, presence=0.0),
            Landmark(x=0.036402590572834015, y=-0.003861718811094761, z=-0.007347520440816879, visibility=0.0, presence=0.0),
            Landmark(x=0.03788445517420769, y=-0.029805485159158707, z=-0.01170967984944582, visibility=0.0, presence=0.0),
            Landmark(x=0.03136403486132622, y=-0.04963252693414688, z=-0.02345612645149231, visibility=0.0, presence=0.0),
            Landmark(x=0.027734559029340744, y=-0.06272327154874802, z=-0.03760094568133354, visibility=0.0, presence=0.0),
        ]
    ],
);

# %% [markdown]
# ### 참고 자료
# [Hand landmarks detection guide for Python (https://developers.google.com/mediapipe/solutions/vision/hand_landmarker/python)](https://developers.google.com/mediapipe/solutions/vision/hand_landmarker/python)
# - ~/anaconda3/envs/mediapipe/Lib/site-packages/mediapipe/tasks/python/vision/hand_landmarker.py
# - ~/anaconda3/envs/mediapipe/Lib/site-packages/mediapipe/tasks/python/components/containers 폴더
